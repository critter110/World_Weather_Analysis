# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#importing citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 618

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2f884d00f0f4cdc032d2eb84286f1ef0"

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        try: 
            city_rain = city_weather["rain"]["1h"]
        except:
            city_rain = 0
            pass
            
        try:
            city_snow = city_weather["snow"]["1h"]
        except:
            city_snow = 0
            pass
        city_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | cabedelo
# Processing Record 3 of Set 1 | bonavista
# Processing Record 4 of Set 1 | lons-le-saunier
# Processing Record 5 of Set 1 | victoria
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | faanui
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | byron bay
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | palauig
# Processing Record 20 of Set 1 | yulara
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | rio grande
# Processing Record 24 of Set 1 | saint george
# Processing Record 25 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 1 | pato branco
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | maniitsoq
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | tanjung morawa
# City not found. Skipping...
# Processing Record 32 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 33 of Set 1 | evensk
# Processing Record 34 of Set 1 | myurego
# Processing Record 35 of Set 1 | ahipara
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | pisco
# Processing Record 40 of Set 1 | joshimath
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | egvekinot
# Processing Record 44 of Set 1 | srednekolymsk
# Processing Record 45 of Set 1 | tambilil
# Processing Record 46 of Set 1 | kambove
# Processing Record 47 of Set 1 | general macarthur
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | pochutla
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | kieta
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | sumbe
# Processing Record 5 of Set 2 | broken hill
# Processing Record 6 of Set 2 | ampanihy
# Processing Record 7 of Set 2 | praia da vitoria
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | sarangani
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | zhangjiakou
# Processing Record 14 of Set 2 | karwar
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 2 | gurupa
# Processing Record 18 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 2 | farmington
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | vestmannaeyjar
# Processing Record 22 of Set 2 | abong mbang
# Processing Record 23 of Set 2 | sao francisco do sul
# Processing Record 24 of Set 2 | slupsk
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | henties bay
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | camacha
# Processing Record 30 of Set 2 | khani
# Processing Record 31 of Set 2 | san juan bautista
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | karratha
# Processing Record 34 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 2 | juegang
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | wielun
# Processing Record 38 of Set 2 | edgewater
# Processing Record 39 of Set 2 | jalu
# Processing Record 40 of Set 2 | fairbanks
# Processing Record 41 of Set 2 | ormara
# Processing Record 42 of Set 2 | vardo
# Processing Record 43 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | punta arenas
# Processing Record 47 of Set 2 | olafsvik
# Processing Record 48 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 2 | hauterive
# Processing Record 50 of Set 2 | reshetylivka
# Processing Record 1 of Set 3 | yatou
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | san cristobal
# Processing Record 5 of Set 3 | kahului
# Processing Record 6 of Set 3 | grand gaube
# Processing Record 7 of Set 3 | hervey bay
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | salalah
# Processing Record 10 of Set 3 | bainbridge
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | ayan
# Processing Record 13 of Set 3 | southbridge
# Processing Record 14 of Set 3 | orangeburg
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | kenai
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | niamey
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | narok
# Processing Record 22 of Set 3 | bordighera
# Processing Record 23 of Set 3 | shingu
# Processing Record 24 of Set 3 | viedma
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | qaqortoq
# Processing Record 28 of Set 3 | kunri
# Processing Record 29 of Set 3 | saint peters
# Processing Record 30 of Set 3 | pangkalanbuun
# Processing Record 31 of Set 3 | cockburn town
# Processing Record 32 of Set 3 | lavrentiya
# Processing Record 33 of Set 3 | kaduna
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | katherine
# Processing Record 36 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 3 | prince rupert
# Processing Record 38 of Set 3 | bloomington
# Processing Record 39 of Set 3 | gizo
# Processing Record 40 of Set 3 | kerema
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | nova olinda do norte
# Processing Record 43 of Set 3 | yellowknife
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | barsovo
# Processing Record 46 of Set 3 | yerbogachen
# Processing Record 47 of Set 3 | kassala
# Processing Record 48 of Set 3 | ostrovnoy
# Processing Record 49 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 50 of Set 3 | xingyi
# Processing Record 1 of Set 4 | zhigansk
# Processing Record 2 of Set 4 | belmopan
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | kulhudhuffushi
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | kavaratti
# Processing Record 7 of Set 4 | manzanillo
# Processing Record 8 of Set 4 | port hueneme
# Processing Record 9 of Set 4 | bumba
# Processing Record 10 of Set 4 | abengourou
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 4 | maunabo
# Processing Record 14 of Set 4 | kautokeino
# Processing Record 15 of Set 4 | stephenville
# Processing Record 16 of Set 4 | tabory
# Processing Record 17 of Set 4 | norsup
# Processing Record 18 of Set 4 | mount gambier
# Processing Record 19 of Set 4 | bulgan
# Processing Record 20 of Set 4 | kupang
# Processing Record 21 of Set 4 | buala
# Processing Record 22 of Set 4 | grao mogol
# Processing Record 23 of Set 4 | walvis bay
# Processing Record 24 of Set 4 | tocopilla
# Processing Record 25 of Set 4 | namatanai
# Processing Record 26 of Set 4 | kearney
# Processing Record 27 of Set 4 | souillac
# Processing Record 28 of Set 4 | vila velha
# Processing Record 29 of Set 4 | vikulovo
# Processing Record 30 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 4 | crossfield
# Processing Record 34 of Set 4 | isangel
# Processing Record 35 of Set 4 | narsaq
# Processing Record 36 of Set 4 | stephenville crossing
# Processing Record 37 of Set 4 | pingzhuang
# Processing Record 38 of Set 4 | ballyshannon
# Processing Record 39 of Set 4 | chicama
# Processing Record 40 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 4 | zeya
# Processing Record 42 of Set 4 | marawi
# Processing Record 43 of Set 4 | iralaya
# Processing Record 44 of Set 4 | cayenne
# Processing Record 45 of Set 4 | ambilobe
# Processing Record 46 of Set 4 | coetupo
# City not found. Skipping...
# Processing Record 47 of Set 4 | biloela
# Processing Record 48 of Set 4 | sur
# Processing Record 49 of Set 4 | ouricuri
# Processing Record 50 of Set 4 | conselheiro pena
# Processing Record 1 of Set 5 | port macquarie
# Processing Record 2 of Set 5 | awbari
# Processing Record 3 of Set 5 | puerto escondido
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | bengkulu
# Processing Record 6 of Set 5 | turukhansk
# Processing Record 7 of Set 5 | ostersund
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 5 | acapulco
# Processing Record 11 of Set 5 | labuhan
# Processing Record 12 of Set 5 | geraldton
# Processing Record 13 of Set 5 | meulaboh
# Processing Record 14 of Set 5 | chalons-en-champagne
# Processing Record 15 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 5 | rio gallegos
# Processing Record 17 of Set 5 | chake chake
# Processing Record 18 of Set 5 | upernavik
# Processing Record 19 of Set 5 | hanzhong
# Processing Record 20 of Set 5 | monster
# Processing Record 21 of Set 5 | georgetown
# Processing Record 22 of Set 5 | ambalavao
# Processing Record 23 of Set 5 | ilulissat
# Processing Record 24 of Set 5 | misratah
# Processing Record 25 of Set 5 | tasiilaq
# Processing Record 26 of Set 5 | coihaique
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | castro
# Processing Record 30 of Set 5 | chom bung
# City not found. Skipping...
# Processing Record 31 of Set 5 | husavik
# Processing Record 32 of Set 5 | tuatapere
# Processing Record 33 of Set 5 | sebring
# Processing Record 34 of Set 5 | vostok
# Processing Record 35 of Set 5 | maun
# Processing Record 36 of Set 5 | warri
# Processing Record 37 of Set 5 | sitka
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | thompson
# Processing Record 40 of Set 5 | keller
# Processing Record 41 of Set 5 | port-gentil
# Processing Record 42 of Set 5 | cam ranh
# Processing Record 43 of Set 5 | khatanga
# Processing Record 44 of Set 5 | grindavik
# Processing Record 45 of Set 5 | whitianga
# Processing Record 46 of Set 5 | havre-saint-pierre
# Processing Record 47 of Set 5 | longyearbyen
# Processing Record 48 of Set 5 | kutum
# Processing Record 49 of Set 5 | chabahar
# Processing Record 50 of Set 5 | ribeira grande
# Processing Record 1 of Set 6 | san ignacio
# Processing Record 2 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 6 | vao
# Processing Record 4 of Set 6 | naze
# Processing Record 5 of Set 6 | conceicao da barra
# Processing Record 6 of Set 6 | manuk mangkaw
# Processing Record 7 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 6 | jipijapa
# Processing Record 9 of Set 6 | riwaka
# Processing Record 10 of Set 6 | sydney
# Processing Record 11 of Set 6 | kununurra
# Processing Record 12 of Set 6 | tikrit
# Processing Record 13 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 6 | stornoway
# Processing Record 15 of Set 6 | nouakchott
# Processing Record 16 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 6 | naliya
# Processing Record 18 of Set 6 | freeport
# Processing Record 19 of Set 6 | smithers
# Processing Record 20 of Set 6 | noshiro
# Processing Record 21 of Set 6 | nouadhibou
# Processing Record 22 of Set 6 | port hawkesbury
# Processing Record 23 of Set 6 | touros
# Processing Record 24 of Set 6 | sao joao da barra
# Processing Record 25 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 6 | wuwei
# Processing Record 27 of Set 6 | komsomolskiy
# Processing Record 28 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 29 of Set 6 | huntington
# Processing Record 30 of Set 6 | noyabrsk
# Processing Record 31 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 6 | francistown
# Processing Record 33 of Set 6 | nemuro
# Processing Record 34 of Set 6 | ust-karsk
# Processing Record 35 of Set 6 | bom conselho
# Processing Record 36 of Set 6 | potsdam
# Processing Record 37 of Set 6 | auki
# Processing Record 38 of Set 6 | luang prabang
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | virovitica
# Processing Record 41 of Set 6 | jibuti
# Processing Record 42 of Set 6 | iaciara
# Processing Record 43 of Set 6 | tazovskiy
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | calvinia
# Processing Record 46 of Set 6 | locri
# Processing Record 47 of Set 6 | marapanim
# Processing Record 48 of Set 6 | portland
# Processing Record 49 of Set 6 | slave lake
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | shimoda
# Processing Record 2 of Set 7 | san francisco
# Processing Record 3 of Set 7 | jardim
# Processing Record 4 of Set 7 | centralia
# Processing Record 5 of Set 7 | sao filipe
# Processing Record 6 of Set 7 | santa cruz
# Processing Record 7 of Set 7 | san quintin
# Processing Record 8 of Set 7 | raudeberg
# Processing Record 9 of Set 7 | santa maria
# Processing Record 10 of Set 7 | lata
# Processing Record 11 of Set 7 | yurga
# Processing Record 12 of Set 7 | namibe
# Processing Record 13 of Set 7 | hambantota
# Processing Record 14 of Set 7 | bubaque
# Processing Record 15 of Set 7 | mamallapuram
# Processing Record 16 of Set 7 | nakanojo
# Processing Record 17 of Set 7 | zhanakorgan
# Processing Record 18 of Set 7 | the pas
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | masvingo
# Processing Record 21 of Set 7 | sorland
# Processing Record 22 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | heiligenhafen
# Processing Record 24 of Set 7 | beringovskiy
# Processing Record 25 of Set 7 | necochea
# Processing Record 26 of Set 7 | sena madureira
# Processing Record 27 of Set 7 | port blair
# Processing Record 28 of Set 7 | bethel
# Processing Record 29 of Set 7 | cherskiy
# Processing Record 30 of Set 7 | belomorsk
# Processing Record 31 of Set 7 | ossora
# Processing Record 32 of Set 7 | huarmey
# Processing Record 33 of Set 7 | trairi
# Processing Record 34 of Set 7 | rocha
# Processing Record 35 of Set 7 | nabire
# Processing Record 36 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | sungaipenuh
# Processing Record 39 of Set 7 | hobyo
# Processing Record 40 of Set 7 | port hedland
# Processing Record 41 of Set 7 | guane
# Processing Record 42 of Set 7 | kuito
# Processing Record 43 of Set 7 | labrea
# Processing Record 44 of Set 7 | constitucion
# Processing Record 45 of Set 7 | gunjur
# Processing Record 46 of Set 7 | abu samrah
# Processing Record 47 of Set 7 | areosa
# Processing Record 48 of Set 7 | yumen
# Processing Record 49 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 7 | amapa
# Processing Record 1 of Set 8 | aasiaat
# Processing Record 2 of Set 8 | iwanai
# Processing Record 3 of Set 8 | bahia honda
# Processing Record 4 of Set 8 | kaeo
# Processing Record 5 of Set 8 | canico
# Processing Record 6 of Set 8 | harper
# Processing Record 7 of Set 8 | nanortalik
# Processing Record 8 of Set 8 | palaia fokaia
# Processing Record 9 of Set 8 | myaundzha
# Processing Record 10 of Set 8 | mitsamiouli
# Processing Record 11 of Set 8 | halifax
# Processing Record 12 of Set 8 | kalmunai
# Processing Record 13 of Set 8 | yuanping
# Processing Record 14 of Set 8 | enterprise
# Processing Record 15 of Set 8 | kodiak
# Processing Record 16 of Set 8 | moba
# Processing Record 17 of Set 8 | osoyoos
# Processing Record 18 of Set 8 | leningradskiy
# Processing Record 19 of Set 8 | lerwick
# Processing Record 20 of Set 8 | oga
# Processing Record 21 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | klaksvik
# Processing Record 24 of Set 8 | monterrey
# Processing Record 25 of Set 8 | torbay
# Processing Record 26 of Set 8 | macae
# Processing Record 27 of Set 8 | koslan
# Processing Record 28 of Set 8 | padang
# Processing Record 29 of Set 8 | waingapu
# Processing Record 30 of Set 8 | mehamn
# Processing Record 31 of Set 8 | yenagoa
# Processing Record 32 of Set 8 | giaginskaya
# Processing Record 33 of Set 8 | baculin
# Processing Record 34 of Set 8 | flin flon
# Processing Record 35 of Set 8 | maceio
# Processing Record 36 of Set 8 | luganville
# Processing Record 37 of Set 8 | galesong
# Processing Record 38 of Set 8 | san blas
# Processing Record 39 of Set 8 | saint anthony
# Processing Record 40 of Set 8 | hirara
# Processing Record 41 of Set 8 | wanaka
# Processing Record 42 of Set 8 | neiafu
# Processing Record 43 of Set 8 | deputatskiy
# Processing Record 44 of Set 8 | damietta
# Processing Record 45 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 8 | ballina
# Processing Record 47 of Set 8 | strezhevoy
# Processing Record 48 of Set 8 | timizart
# Processing Record 49 of Set 8 | xichang
# Processing Record 50 of Set 8 | lalin
# Processing Record 1 of Set 9 | mnogovershinnyy
# Processing Record 2 of Set 9 | shiyan
# Processing Record 3 of Set 9 | boende
# Processing Record 4 of Set 9 | sistranda
# Processing Record 5 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 9 | bairiki
# Processing Record 7 of Set 9 | namanyere
# Processing Record 8 of Set 9 | mayo
# Processing Record 9 of Set 9 | jumla
# Processing Record 10 of Set 9 | hoi an
# Processing Record 11 of Set 9 | nago
# Processing Record 12 of Set 9 | horta
# Processing Record 13 of Set 9 | kavieng
# Processing Record 14 of Set 9 | adre
# Processing Record 15 of Set 9 | nogliki
# Processing Record 16 of Set 9 | puerto narino
# Processing Record 17 of Set 9 | san patricio
# Processing Record 18 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 19 of Set 9 | vieques
# Processing Record 20 of Set 9 | boa vista
# Processing Record 21 of Set 9 | kantabanji
# Processing Record 22 of Set 9 | salinopolis
# Processing Record 23 of Set 9 | kirgiz-miyaki
# Processing Record 24 of Set 9 | tuy hoa
# Processing Record 25 of Set 9 | goundam
# Processing Record 26 of Set 9 | codrington
# Processing Record 27 of Set 9 | dax
# Processing Record 28 of Set 9 | kibala
# Processing Record 29 of Set 9 | buin
# Processing Record 30 of Set 9 | nuuk
# Processing Record 31 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 9 | vila franca do campo
# Processing Record 33 of Set 9 | belmonte
# Processing Record 34 of Set 9 | baykit
# Processing Record 35 of Set 9 | coolum beach
# Processing Record 36 of Set 9 | luderitz
# Processing Record 37 of Set 9 | tiznit
# Processing Record 38 of Set 9 | shellbrook
# Processing Record 39 of Set 9 | beloha
# Processing Record 40 of Set 9 | kisangani
# Processing Record 41 of Set 9 | guanhaes
# Processing Record 42 of Set 9 | khakhea
# Processing Record 43 of Set 9 | ystad
# Processing Record 44 of Set 9 | ayaviri
# Processing Record 45 of Set 9 | puri
# Processing Record 46 of Set 9 | suluq
# Processing Record 47 of Set 9 | dudinka
# Processing Record 48 of Set 9 | durham
# Processing Record 49 of Set 9 | ipswich
# Processing Record 50 of Set 9 | aljezur
# Processing Record 1 of Set 10 | gladstone
# Processing Record 2 of Set 10 | presidencia roque saenz pena
# Processing Record 3 of Set 10 | nizwa
# Processing Record 4 of Set 10 | poli
# Processing Record 5 of Set 10 | saint-pierre
# Processing Record 6 of Set 10 | aklavik
# Processing Record 7 of Set 10 | gulariya
# Processing Record 8 of Set 10 | gorom-gorom
# Processing Record 9 of Set 10 | maua
# Processing Record 10 of Set 10 | keflavik
# Processing Record 11 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 12 of Set 10 | fortuna
# Processing Record 13 of Set 10 | novomykolayivka
# Processing Record 14 of Set 10 | mehran
# Processing Record 15 of Set 10 | ewa beach
# Processing Record 16 of Set 10 | toyooka
# Processing Record 17 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 10 | sakaiminato
# Processing Record 19 of Set 10 | verkhoyansk
# Processing Record 20 of Set 10 | syracuse
# Processing Record 21 of Set 10 | hammerfest
# Processing Record 22 of Set 10 | san pedro de ycuamandiyu
# Processing Record 23 of Set 10 | tilichiki
# Processing Record 24 of Set 10 | chiungutwa
# Processing Record 25 of Set 10 | baniyas
# Processing Record 26 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 10 | dunedin
# Processing Record 28 of Set 10 | burica
# City not found. Skipping...
# Processing Record 29 of Set 10 | sibu
# Processing Record 30 of Set 10 | sayyan
# Processing Record 31 of Set 10 | wanning
# Processing Record 32 of Set 10 | missoula
# Processing Record 33 of Set 10 | kozhva
# Processing Record 34 of Set 10 | sunrise manor
# Processing Record 35 of Set 10 | alugan
# Processing Record 36 of Set 10 | cidreira
# Processing Record 37 of Set 10 | visby
# Processing Record 38 of Set 10 | santa paula
# Processing Record 39 of Set 10 | kireka
# Processing Record 40 of Set 10 | kruisfontein
# Processing Record 41 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 42 of Set 10 | hami
# Processing Record 43 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 10 | jutai
# Processing Record 45 of Set 10 | acarau
# Processing Record 46 of Set 10 | pangai
# Processing Record 47 of Set 10 | piopio
# Processing Record 48 of Set 10 | tottori
# Processing Record 49 of Set 10 | chegdomyn
# Processing Record 50 of Set 10 | zyryanka
# Processing Record 1 of Set 11 | allanmyo
# City not found. Skipping...
# Processing Record 2 of Set 11 | pemangkat
# Processing Record 3 of Set 11 | avera
# Processing Record 4 of Set 11 | gashua
# Processing Record 5 of Set 11 | soyo
# Processing Record 6 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 11 | uyemskiy
# Processing Record 8 of Set 11 | camana
# Processing Record 9 of Set 11 | ziro
# Processing Record 10 of Set 11 | acajutla
# Processing Record 11 of Set 11 | almaznyy
# Processing Record 12 of Set 11 | berlevag
# Processing Record 13 of Set 11 | pasir gudang
# Processing Record 14 of Set 11 | mayya
# Processing Record 15 of Set 11 | pombia
# Processing Record 16 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 11 | pacific grove
# Processing Record 19 of Set 11 | pecos
# Processing Record 20 of Set 11 | alyangula
# Processing Record 21 of Set 11 | golkoy
# Processing Record 22 of Set 11 | san isidro
# Processing Record 23 of Set 11 | lorengau
# Processing Record 24 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 11 | christchurch
# Processing Record 26 of Set 11 | deer lake
# Processing Record 27 of Set 11 | pampa
# Processing Record 28 of Set 11 | saint-augustin
# Processing Record 29 of Set 11 | garowe
# Processing Record 30 of Set 11 | dharchula
# Processing Record 31 of Set 11 | caucaia
# Processing Record 32 of Set 11 | verkhnevilyuysk
# Processing Record 33 of Set 11 | burns lake
# Processing Record 34 of Set 11 | umba
# Processing Record 35 of Set 11 | arlit
# Processing Record 36 of Set 11 | vazante
# Processing Record 37 of Set 11 | nsunga
# Processing Record 38 of Set 11 | masterton
# Processing Record 39 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 11 | marsh harbour
# Processing Record 41 of Set 11 | half moon bay
# Processing Record 42 of Set 11 | polyarnyy
# Processing Record 43 of Set 11 | cape coast
# Processing Record 44 of Set 11 | lexington
# Processing Record 45 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 46 of Set 11 | moose factory
# Processing Record 47 of Set 11 | atsiki
# City not found. Skipping...
# Processing Record 48 of Set 11 | riyadh
# Processing Record 49 of Set 11 | oistins
# Processing Record 50 of Set 11 | hashtrud
# Processing Record 1 of Set 12 | duz
# City not found. Skipping...
# Processing Record 2 of Set 12 | zhangye
# Processing Record 3 of Set 12 | zhangzhou
# Processing Record 4 of Set 12 | pachino
# Processing Record 5 of Set 12 | port augusta
# Processing Record 6 of Set 12 | ayagoz
# Processing Record 7 of Set 12 | sabha
# Processing Record 8 of Set 12 | tall kayf
# Processing Record 9 of Set 12 | iqaluit
# Processing Record 10 of Set 12 | bograd
# Processing Record 11 of Set 12 | shakawe
# Processing Record 12 of Set 12 | oparino
# Processing Record 13 of Set 12 | svetlogorsk
# Processing Record 14 of Set 12 | mahibadhoo
# Processing Record 15 of Set 12 | okhotsk
# Processing Record 16 of Set 12 | chignahuapan
# Processing Record 17 of Set 12 | abu dhabi
# Processing Record 18 of Set 12 | dandong
# Processing Record 19 of Set 12 | ishinomaki
# Processing Record 20 of Set 12 | cabo san lucas
# Processing Record 21 of Set 12 | ko samui
# Processing Record 22 of Set 12 | hualmay
# Processing Record 23 of Set 12 | pilar
# Processing Record 24 of Set 12 | ulladulla
# Processing Record 25 of Set 12 | umm lajj
# Processing Record 26 of Set 12 | alpena
# Processing Record 27 of Set 12 | plettenberg bay
# Processing Record 28 of Set 12 | naifaru
# Processing Record 29 of Set 12 | mandalgovi
# Processing Record 30 of Set 12 | road town
# Processing Record 31 of Set 12 | inta
# Processing Record 32 of Set 12 | namie
# Processing Record 33 of Set 12 | susanville
# Processing Record 34 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 12 | solnechnyy
# Processing Record 36 of Set 12 | el tocuyo
# Processing Record 37 of Set 12 | sangar
# Processing Record 38 of Set 12 | eatonton
# Processing Record 39 of Set 12 | talara
# Processing Record 40 of Set 12 | araioses
# Processing Record 41 of Set 12 | zharkent
# Processing Record 42 of Set 12 | los banos
# Processing Record 43 of Set 12 | songea
# Processing Record 44 of Set 12 | mount isa
# Processing Record 45 of Set 12 | nanning
# Processing Record 46 of Set 12 | buchanan
# Processing Record 47 of Set 12 | planeta rica
# Processing Record 48 of Set 12 | elizabeth city
# Processing Record 49 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 12 | batagay-alyta
# Processing Record 1 of Set 13 | monte santo
# Processing Record 2 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 3 of Set 13 | timmins
# Processing Record 4 of Set 13 | saint-leu
# Processing Record 5 of Set 13 | seminole
# Processing Record 6 of Set 13 | santa lucia
# Processing Record 7 of Set 13 | huilong
# Processing Record 8 of Set 13 | buluang
# Processing Record 9 of Set 13 | belyy yar
# Processing Record 10 of Set 13 | esperance
# Processing Record 11 of Set 13 | lukow
# Processing Record 12 of Set 13 | ancud
# Processing Record 13 of Set 13 | calama
# Processing Record 14 of Set 13 | coffs harbour
# Processing Record 15 of Set 13 | darhan
# Processing Record 16 of Set 13 | saint-francois
# Processing Record 17 of Set 13 | dutlwe
# Processing Record 18 of Set 13 | roebourne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 561

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Cabedelo  -6.98  -34.83     75.20        94          20        4.70
# 1        Bonavista  48.65  -53.11     53.01        86         100        7.00
# 2  Lons-Le-Saunier  46.75    5.75     66.99        82          21        3.24
# 3         Victoria  22.29  114.16     88.00        74         100       11.99
# 4    Mar Del Plata -38.00  -57.56     46.99        70         100       10.29
# 5       Nikolskoye  59.70   30.79     51.80        81          20        8.95
# 6          Rikitea -23.12 -134.97     67.80        72           5       23.22
# 7            Pevek  69.70  170.31     43.00       100         100        0.96
# 8        Jamestown  42.10  -79.24     82.99        61           1        3.36
# 9          Mataura -46.19  168.86     46.38        87          96        7.14
#
#   Country  Rain (inches)  Snow (inches) Current Description  \
# 0      BR           0.00              0          few clouds
# 1      CA           0.00              0     overcast clouds
# 2      FR           0.00              0          few clouds
# 3      HK           0.00              0     overcast clouds
# 4      AR           0.00              0     overcast clouds
# 5      RU           0.00              0          few clouds
# 6      PF           0.12              0          light rain
# 7      RU           0.11              0          light rain
# 8      US           0.00              0           clear sky
# 9      NZ           0.00              0     overcast clouds
#
#                   Date
# 0  2020-07-10 00:09:33
# 1  2020-07-10 00:09:33
# 2  2020-07-10 00:09:33
# 3  2020-07-10 00:05:24
# 4  2020-07-10 00:06:17
# 5  2020-07-10 00:09:33
# 6  2020-07-10 00:09:34
# 7  2020-07-10 00:09:34
# 8  2020-07-10 00:06:53
# 9  2020-07-10 00:09:34

# %%
# Changing the order of the columns
newColumnOrder = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Current Description','Rain (inches)','Snow (inches)']
city_data_df = city_data_df[newColumnOrder]
city_data_df
# Out:
#                 City Country                 Date    Lat     Lng  Max Temp  \
# 0           Cabedelo      BR  2020-07-10 00:09:33  -6.98  -34.83     75.20
# 1          Bonavista      CA  2020-07-10 00:09:33  48.65  -53.11     53.01
# 2    Lons-Le-Saunier      FR  2020-07-10 00:09:33  46.75    5.75     66.99
# 3           Victoria      HK  2020-07-10 00:05:24  22.29  114.16     88.00
# 4      Mar Del Plata      AR  2020-07-10 00:06:17 -38.00  -57.56     46.99
# ..               ...     ...                  ...    ...     ...       ...
# 556    Coffs Harbour      AU  2020-07-10 00:10:53 -30.30  153.13     60.80
# 557           Darhan      MN  2020-07-10 00:10:53  49.49  105.92     59.34
# 558   Saint-Francois      FR  2020-07-10 00:10:53  46.42    3.91     69.01
# 559           Dutlwe      BW  2020-07-10 00:10:53 -23.98   23.90     52.84
# 560        Roebourne      AU  2020-07-10 00:10:54 -20.78  117.13     67.03
#
#      Humidity  Cloudiness  Wind Speed Current Description  Rain (inches)  \
# 0          94          20        4.70          few clouds            0.0
# 1          86         100        7.00     overcast clouds            0.0
# 2          82          21        3.24          few clouds            0.0
# 3          74         100       11.99     overcast clouds            0.0
# 4          70         100       10.29     overcast clouds            0.0
# ..        ...         ...         ...                 ...            ...
# 556        87          90        3.15     overcast clouds            0.0
# 557        77         100        6.49     overcast clouds            0.0
# 558        72           5        3.36           clear sky            0.0
# 559        55           0        7.78           clear sky            0.0
# 560        30          18       19.37          few clouds            0.0
#
#      Snow (inches)
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 556              0
# 557              0
# 558              0
# 559              0
# 560              0
#
# [561 rows x 12 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
